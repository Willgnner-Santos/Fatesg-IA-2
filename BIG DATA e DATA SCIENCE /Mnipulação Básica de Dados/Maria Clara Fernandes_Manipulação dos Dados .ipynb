# %%
#Visualização e familiarização com o ambente com o Ambiente de trabalho e manipulação básica de dados
#Aluna: Maria Clara Fernandes

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
#Armazenamento de Diretório
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-bdc145e1-fbcc-4093-a6a2-49755f5bd17f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdc145e1-fbcc-4093-a6a2-49755f5bd17f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -lh #lista os arquivoss
#(!-definição de comenddos no terminaal linux, ls-lista arquivos e pastas, -lh -lista em formato detalhado e converte o resultados de bytes par respostas mai simplificadas)
# Out:
# total 3.3M
# -rw-r--r-- 1 root root 3.3M Nov 29 18:21 netflix_titles.csv
# drwxr-xr-x 1 root root 4.0K Nov 20 14:30 sample_data

# %%
os.listdir()# nessa parte ele lista o diretório
# Out:
# ['.config', 'netflix_titles.csv', 'sample_data']

# %%
df = pd.read_csv('netflix_titles.csv')
df.head(8)
df.tail(8)
#Mostra as 8 primeiras linhas e as 8 últimas
# Out:
#      show_id     type               title         director  \
# 8799   s8800    Movie               Zenda   Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai              NaN
# 8801   s8802    Movie             Zinzana  Majid Al Ansari
# 8802   s8803    Movie              Zodiac    David Fincher
# 8803   s8804  TV Show         Zombie Dumb              NaN
# 8804   s8805    Movie          Zombieland  Ruben Fleischer
# 8805   s8806    Movie                Zoom     Peter Hewitt
# 8806   s8807    Movie              Zubaan      Mozez Singh
#
#                                                    cast  \
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
linhas, colunas = df.shape
print(f"Linhas: {linhas}")
print(f"Colunas: {colunas}")
# Out:
# Linhas: 8807
# Colunas: 12

# %%
### Impressões gerais sobre o dataset
"""
O dataset contém 8807 linhas e 12 colunas. Possui tipos de dados categóricos.
As informações estão dispostas em colunas de datas de lançamento, nome,tipo, elenco, país,  dentre outras informaçõess
relacionadas aos ilme da plataforma netflix.
O dataset é adequado para análises iniciais de ciência de dados e possui dados relativamente limpos, apesar
o tamanho há uma variedade de dados que permite análises profundas e detalhadas.
"""
# Out:
# '\nO dataset contém 8807 linhas e 12 colunas. Possui tipos de dados categóricos.\nAs informações estão dispostas em colunas de datas de lançamento, nome,tipo, elenco, país,  dentre outras informaçõess\nrelacionadas aos ilme da plataforma netflix.\nO dataset é adequado para análises iniciais de ciência de dados e possui dados relativamente limpos, apesar\no tamanho há uma variedade de dados que permite análises profundas e detalhadas.\n'
