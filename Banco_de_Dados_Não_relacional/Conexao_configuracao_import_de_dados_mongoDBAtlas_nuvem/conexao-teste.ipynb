# %%
# Primeira parte
import pandas as pd
import pymongo
import urllib.parse

# Definir o caminho do arquivo CSV
csv_path = r"J:\Meu Drive\Classroom\Banco de Dados Não-Relacional Curso de IA, 2º semestre (2025 2)\Conexão - configuração - import de dados - MongoDB Atlas - Nuvem\IMDB top 1000.csv"

# Ler o CSV usando Pandas
df = pd.read_csv(csv_path)

# %%
# print(df.head(6))

# %%
# Segunda parte
import pymongo
import urllib.parse

# Definir usuário e senha
username = "leticiapeixotoadv_db_user"
password = ""#retirada a senha para postar no github

# Codificar a senha (caso tenha caracteres especiais)
password_encoded = urllib.parse.quote_plus(password)

# Criar a URI corretamente formatada
cluster_address = "cluster0.fhxqbwl.mongodb.net" # url string mongodb+srv://leticiapeixotoadv_db_user:Ot8r9f53MGPeUJwq@cluster0.fhxqbwl.mongodb.net/?appName=Cluster0
MONGO_URI = f"mongodb+srv://{username}:{password_encoded}@{cluster_address}/?retryWrites=true&w=majority&appName=Cluster0"

# Conectar ao MongoDB Atlas
client = pymongo.MongoClient(MONGO_URI)

# Acessar o banco e a coleção
db = client["filmes"]
collection = db["filmes-series"]

# Teste de conexão (Ping)
try:
    client.admin.command('ping')
    print("Conexão com MongoDB Atlas estabelecida com sucesso!")
except Exception as e:
    print(f"Erro ao conectar: {e}")
# Out:
# Conexão com MongoDB Atlas estabelecida com sucesso!

# %%
# Terceira parte

# Converte o DataFrame (df) em uma lista de dicionários, onde cada linha vira um "registro" (record) separado.
# df.to_dict() → transforma o DataFrame em um dicionário.
# orient="records" → define o formato da conversão: cada linha = 1 dicionário (ideal para inserir no MongoDB).
dados_json = df.to_dict(orient="records")

# Ou seja: orient="records" instrui o pandas a gerar uma lista de documentos JSON, 
# cada um representando uma linha da tabela, que o MongoDB entende perfeitamente.

# Insere todos os documentos (dicionários) da lista 'dados_json' dentro da coleção MongoDB de uma só vez.
# 'collection' → é o objeto que representa a coleção (tabela) no banco MongoDB.
# 'insert_many()' → comando do PyMongo que insere múltiplos documentos de uma vez (em lote).
# 'dados_json' → é a lista de dicionários criada antes (cada item = um documento/linha).
collection.insert_many(dados_json)

print(" Dados enviados para o MongoDB Atlas com sucesso!")
# Out:
#  Dados enviados para o MongoDB Atlas com sucesso!

# %% [markdown]
# Consultas no Banco

# %%
for doc in collection.find({"Genre": "Drama"}):
    print(doc["Title"], "-", doc["Rate"])

# Retorna todos os filmes onde o campo "Genre" é "Drama".
# Você pode alterar para "Action", "Comedy", etc.
# Out:
# 1. The Shawshank Redemption (1994) - 9.3
# 10. Fight Club (1999) - 8.8
# 19. One Flew Over the Cuckoo's Nest (1975) - 8.7
# 40. American History X (1998) - 8.5
# 45. Cinema Paradiso (1988) - 8.5
# 54. Capernaum (2018) - 8.4
# 88. The Hunt (2012) - 8.3
# 91. 7 Kogustaki Mucize (2019) - 8.3
# 98. Requiem for a Dream (2000) - 8.3
# 99. American Beauty (1999) - 8.3
# 122. Ikiru (1952) - 8.3
# 123. Bicycle Thieves (1948) - 8.3
# 141. Udaan (2010) - 8.2
# 149. There Will Be Blood (2007) - 8.2
# 153. Black (2005) - 8.2
# 155. Swades (2004) - 8.2
# 185. Tokyo Story (1953) - 8.2
# 187. All About Eve (1950) - 8.2
# 197. Mommy (I) (2014) - 8.1
# 202. Winter Sleep (2014) - 8.1
# 223. Gran Torino (2008) - 8.1
# 252. Trainspotting (1996) - 8.1
# 267. Paris, Texas (1984) - 8.1
# 272. Fanny and Alexander (1982) - 8.1
# 278. Network (1976) - 8.1
# 283. Cries & Whispers (1972) - 8.1
# 295. The Virgin Spring (1960) - 8.1
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 1. The Shawshank Redemption (1994) - 9.3
# 10. Fight Club (1999) - 8.8
# 19. One Flew Over the Cuckoo's Nest (1975) - 8.7
# 40. American History X (1998) - 8.5
# 45. Cinema Paradiso (1988) - 8.5
# 54. Capernaum (2018) - 8.4
# 88. The Hunt (2012) - 8.3
# 91. 7 Kogustaki Mucize (2019) - 8.3
# 98. Requiem for a Dream (2000) - 8.3
# 99. American Beauty (1999) - 8.3
# 122. Ikiru (1952) - 8.3
# 123. Bicycle Thieves (1948) - 8.3
# 141. Udaan (2010) - 8.2
# 149. There Will Be Blood (2007) - 8.2
# 153. Black (2005) - 8.2
# 155. Swades (2004) - 8.2
# 185. Tokyo Story (1953) - 8.2
# 187. All About Eve (1950) - 8.2
# 197. Mommy (I) (2014) - 8.1
# 202. Winter Sleep (2014) - 8.1
# 223. Gran Torino (2008) - 8.1
# 252. Trainspotting (1996) - 8.1
# 267. Paris, Texas (1984) - 8.1
# 272. Fanny and Alexander (1982) - 8.1
# 278. Network (1976) - 8.1
# 283. Cries & Whispers (1972) - 8.1
# 295. The Virgin Spring (1960) - 8.1
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1

# %%
for doc in collection.find({"Rate": {"$gt": 8.5}}):
    print(doc["Title"], "-", doc["Rate"])

# O operador $gt significa greater than (maior que).
# Mostra filmes com nota superior a 8.5 no IMDB.
# Out:
# 1. The Shawshank Redemption (1994) - 9.3
# 2. The Godfather (1972) - 9.2
# 3. The Dark Knight (2008) - 9.0
# 4. The Godfather: Part II (1974) - 9.0
# 5. The Lord of the Rings: The Return of the King (2003) - 8.9
# 6. Pulp Fiction (1994) - 8.9
# 7. Schindler's List (1993) - 8.9
# 8. 12 Angry Men (1957) - 8.9
# 9. Inception (2010) - 8.8
# 10. Fight Club (1999) - 8.8
# 11. The Lord of the Rings: The Fellowship of the Ring (2001) - 8.8
# 12. Forrest Gump (1994) - 8.8
# 13. The Good, the Bad and the Ugly (1966) - 8.8
# 14. Hamilton (2020) - 8.7
# 15. The Lord of the Rings: The Two Towers (2002) - 8.7
# 16. The Matrix (1999) - 8.7
# 17. Goodfellas (1990) - 8.7
# 18. Star Wars: Episode V - The Empire Strikes Back (1980) - 8.7
# 19. One Flew Over the Cuckoo's Nest (1975) - 8.7
# 20. Parasite (2019) - 8.6
# 21. Interstellar (2014) - 8.6
# 22. City of God (2002) - 8.6
# 23. Spirited Away (2001) - 8.6
# 24. Saving Private Ryan (1998) - 8.6
# 25. The Green Mile (1999) - 8.6
# 26. Life Is Beautiful (1997) - 8.6
# 27. Se7en (1995) - 8.6
# 28. The Silence of the Lambs (1991) - 8.6
# 29. Star Wars: Episode IV - A New Hope (1977) - 8.6
# 30. Harakiri (1962) - 8.6
# 31. Seven Samurai (1954) - 8.6
# 32. It's a Wonderful Life (1946) - 8.6
# 1. The Shawshank Redemption (1994) - 9.3
# 2. The Godfather (1972) - 9.2
# 3. The Dark Knight (2008) - 9.0
# 4. The Godfather: Part II (1974) - 9.0
# 5. The Lord of the Rings: The Return of the King (2003) - 8.9
# 6. Pulp Fiction (1994) - 8.9
# 7. Schindler's List (1993) - 8.9
# 8. 12 Angry Men (1957) - 8.9
# 9. Inception (2010) - 8.8
# 10. Fight Club (1999) - 8.8
# 11. The Lord of the Rings: The Fellowship of the Ring (2001) - 8.8
# 12. Forrest Gump (1994) - 8.8
# 13. The Good, the Bad and the Ugly (1966) - 8.8
# 14. Hamilton (2020) - 8.7
# 15. The Lord of the Rings: The Two Towers (2002) - 8.7
# 16. The Matrix (1999) - 8.7
# 17. Goodfellas (1990) - 8.7
# 18. Star Wars: Episode V - The Empire Strikes Back (1980) - 8.7
# 19. One Flew Over the Cuckoo's Nest (1975) - 8.7
# 20. Parasite (2019) - 8.6
# 21. Interstellar (2014) - 8.6
# 22. City of God (2002) - 8.6
# 23. Spirited Away (2001) - 8.6
# 24. Saving Private Ryan (1998) - 8.6
# 25. The Green Mile (1999) - 8.6
# 26. Life Is Beautiful (1997) - 8.6
# 27. Se7en (1995) - 8.6
# 28. The Silence of the Lambs (1991) - 8.6
# 29. Star Wars: Episode IV - A New Hope (1977) - 8.6
# 30. Harakiri (1962) - 8.6
# 31. Seven Samurai (1954) - 8.6
# 32. It's a Wonderful Life (1946) - 8.6

# %%
top5 = collection.find().sort("Rate", -1).limit(5)
for doc in top5:
    print(doc["Title"], "-", doc["Rate"])

# Ordena do maior para o menor (-1) e mostra apenas 5 resultados.
# Out:
# 1. The Shawshank Redemption (1994) - 9.3
# 1. The Shawshank Redemption (1994) - 9.3
# 2. The Godfather (1972) - 9.2
# 2. The Godfather (1972) - 9.2
# 4. The Godfather: Part II (1974) - 9.0

# %%
query = {"Genre": "Drama", "Metascore": {"$gt": 90}}
for doc in collection.find(query, {"Title": 1, "Metascore": 1, "_id": 0}):
    print(doc)

# Filtra por dois critérios: gênero e metascore alto.
# O segundo parâmetro {} define quais campos mostrar (1 = incluir, 0 = excluir).
# Out:
# {'Title': '149. There Will Be Blood (2007)', 'Metascore': 93.0}
# {'Title': '187. All About Eve (1950)', 'Metascore': 98.0}
# {'Title': '272. Fanny and Alexander (1982)', 'Metascore': 100.0}
# {'Title': '149. There Will Be Blood (2007)', 'Metascore': 93.0}
# {'Title': '187. All About Eve (1950)', 'Metascore': 98.0}
# {'Title': '272. Fanny and Alexander (1982)', 'Metascore': 100.0}

# %%
count = collection.count_documents({"Certificate": "R"})
print("Total de filmes com classificação R:", count)

## Conta quantos documentos possuem o valor "R" no campo "Certificate".
# Out:
# Total de filmes com classificação R: 690

# %%
# No caso funciona rodando no próprio Banco na Nuvem

# Mostra todos os documentos onde o campo Genre é exatamente "Drama".
{ "Genre": "Drama" }

# Filmes com nota (Rate) maior que 9
{ "Rate": { "$gt": 9 } }

# Você também pode combinar com expressões regulares para buscas por texto:
{ "Description": { "$regex": "prison", "$options": "i" } }
# Out:
# {'Description': {'$regex': 'prison', '$options': 'i'}}

# %%
# Exemplo: Agrupar por Gênero e calcular a média das notas
pipeline = [
    {
        "$group": {
            "_id": "$Genre",                  # Agrupa por Gênero
            "media_rate": {"$avg": "$Rate"},  # Calcula média
            "qtd_filmes": {"$sum": 1}         # Conta quantidade
        }
    },
    { "$sort": { "qtd_filmes": -1 } }         # Ordena do que tem mais filmes para o menos
]

resultado = collection.aggregate(pipeline)

print("Agregação por Gênero:")
for doc in resultado:
    print(doc)
# Out:
# Agregação por Gênero:
# {'_id': 'Drama', 'media_rate': 8.090816326530613, 'qtd_filmes': 196}
# {'_id': 'Biography, Drama', 'media_rate': 8.01086956521739, 'qtd_filmes': 92}
# {'_id': 'Drama, Romance', 'media_rate': 8.05813953488372, 'qtd_filmes': 86}
# {'_id': 'Crime, Drama', 'media_rate': 8.185294117647059, 'qtd_filmes': 68}
# {'_id': 'Animation, Adventure, Comedy', 'media_rate': 8.035294117647059, 'qtd_filmes': 68}
# {'_id': 'Comedy, Drama, Romance', 'media_rate': 8.070588235294117, 'qtd_filmes': 68}
# {'_id': 'Biography, Drama, History', 'media_rate': 8.127272727272727, 'qtd_filmes': 66}
# {'_id': 'Comedy, Drama', 'media_rate': 8.05151515151515, 'qtd_filmes': 66}
# {'_id': 'Action, Adventure, Comedy', 'media_rate': 8.03103448275862, 'qtd_filmes': 58}
# {'_id': 'Action, Crime, Drama', 'media_rate': 8.1, 'qtd_filmes': 56}
# {'_id': 'Crime, Drama, Thriller', 'media_rate': 8.154166666666667, 'qtd_filmes': 48}
# {'_id': 'Drama, Mystery, Thriller', 'media_rate': 8.038888888888888, 'qtd_filmes': 36}
# {'_id': 'Drama, War', 'media_rate': 8.18235294117647, 'qtd_filmes': 34}
# {'_id': 'Animation, Action, Adventure', 'media_rate': 8.03125, 'qtd_filmes': 32}
# {'_id': 'Comedy, Romance', 'media_rate': 8.11875, 'qtd_filmes': 32}
# {'_id': 'Drama, History', 'media_rate': 8.053333333333333, 'qtd_filmes': 30}
# {'_id': 'Adventure, Drama, Thriller', 'media_rate': 8.066666666666666, 'qtd_filmes': 30}
# {'_id': 'Action, Crime, Thriller', 'media_rate': 8.006666666666666, 'qtd_filmes': 30}
# {'_id': 'Action, Adventure, Drama', 'media_rate': 8.3, 'qtd_filmes': 26}
# {'_id': 'Action, Adventure, Sci-Fi', 'media_rate': 8.141666666666667, 'qtd_filmes': 24}
# {'_id': 'Drama, Thriller', 'media_rate': 8.054545454545455, 'qtd_filmes': 22}
# {'_id': 'Action, Adventure, Fantasy', 'media_rate': 8.16, 'qtd_filmes': 20}
# {'_id': 'Crime, Drama, Mystery', 'media_rate': 8.25, 'qtd_filmes': 20}
# {'_id': 'Drama, Family', 'media_rate': 8.08, 'qtd_filmes': 20}
# {'_id': 'Action, Biography, Drama', 'media_rate': 8.059999999999999, 'qtd_filmes': 20}
# {'_id': 'Action, Drama, Mystery', 'media_rate': 8.11111111111111, 'qtd_filmes': 18}
# {'_id': 'Crime, Thriller', 'media_rate': 8.055555555555555, 'qtd_filmes': 18}
# {'_id': 'Adventure, Biography, Drama', 'media_rate': 8.044444444444444, 'qtd_filmes': 18}
# {'_id': 'Animation, Adventure, Drama', 'media_rate': 8.066666666666666, 'qtd_filmes': 18}
# {'_id': 'Drama, Mystery, Sci-Fi', 'media_rate': 8.066666666666666, 'qtd_filmes': 18}
# {'_id': 'Drama, Mystery, Romance', 'media_rate': 8.11111111111111, 'qtd_filmes': 18}
# {'_id': 'Drama, Film-Noir', 'media_rate': 8.133333333333333, 'qtd_filmes': 18}
# {'_id': 'Animation, Family, Fantasy', 'media_rate': 8.025, 'qtd_filmes': 16}
# {'_id': 'Adventure, Drama, Fantasy', 'media_rate': 8.0125, 'qtd_filmes': 16}
# {'_id': 'Adventure, Drama, War', 'media_rate': 8.125, 'qtd_filmes': 16}
# {'_id': 'Biography, Drama, Music', 'media_rate': 8.0625, 'qtd_filmes': 16}
# {'_id': 'Adventure, Drama, Sci-Fi', 'media_rate': 8.075, 'qtd_filmes': 16}
# {'_id': 'Action, Thriller', 'media_rate': 8.025, 'qtd_filmes': 16}
# {'_id': 'Drama, Music, Romance', 'media_rate': 8.1, 'qtd_filmes': 16}
# {'_id': 'Adventure, Comedy, Sci-Fi', 'media_rate': 8.0625, 'qtd_filmes': 16}
# {'_id': 'Drama, History, Romance', 'media_rate': 8.1, 'qtd_filmes': 16}
# {'_id': 'Action, Drama, Thriller', 'media_rate': 8.025, 'qtd_filmes': 16}
# {'_id': 'Drama, Romance, Sci-Fi', 'media_rate': 8.0375, 'qtd_filmes': 16}
# {'_id': 'Action, Mystery, Thriller', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Drama, History, Thriller', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Film-Noir, Mystery, Thriller', 'media_rate': 8.1, 'qtd_filmes': 14}
# {'_id': 'Animation, Action, Crime', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Biography, Drama, Thriller', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Animation, Crime, Mystery', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Action, Adventure, Thriller', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Fantasy, Horror, Mystery', 'media_rate': 8.1, 'qtd_filmes': 14}
# {'_id': 'Animation, Biography, Drama', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Comedy, Drama, Music', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Comedy, Fantasy, Romance', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Action, Crime, Comedy', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Crime, Drama, Musical', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Mystery, Sci-Fi, Thriller', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Crime, Drama, Romance', 'media_rate': 8.0, 'qtd_filmes': 14}
# {'_id': 'Biography, Crime, Drama', 'media_rate': 8.274999999999999, 'qtd_filmes': 8}
# {'_id': 'Mystery, Thriller', 'media_rate': 8.275, 'qtd_filmes': 8}
# {'_id': 'Animation, Adventure, Family', 'media_rate': 8.4, 'qtd_filmes': 8}
# {'_id': 'Comedy, Crime, Drama', 'media_rate': 8.175, 'qtd_filmes': 8}
# {'_id': 'Action, Adventure', 'media_rate': 8.3, 'qtd_filmes': 8}
# {'_id': 'Action, Drama, War', 'media_rate': 8.200000000000001, 'qtd_filmes': 6}
# {'_id': 'Drama, Western', 'media_rate': 8.233333333333333, 'qtd_filmes': 6}
# {'_id': 'Action, Comedy, Crime', 'media_rate': 8.166666666666666, 'qtd_filmes': 6}
# {'_id': 'Drama, Music', 'media_rate': 8.233333333333333, 'qtd_filmes': 6}
# {'_id': 'Adventure, Drama, History', 'media_rate': 8.133333333333333, 'qtd_filmes': 6}
# {'_id': 'Western', 'media_rate': 8.533333333333333, 'qtd_filmes': 6}
# {'_id': 'Action, Drama', 'media_rate': 8.166666666666666, 'qtd_filmes': 6}
# {'_id': 'Adventure, Drama', 'media_rate': 8.1, 'qtd_filmes': 6}
# {'_id': 'Action, Sci-Fi', 'media_rate': 8.6, 'qtd_filmes': 4}
# {'_id': 'Adventure, Comedy, Drama', 'media_rate': 8.2, 'qtd_filmes': 4}
# {'_id': 'Comedy', 'media_rate': 8.25, 'qtd_filmes': 4}
# {'_id': 'Biography, Comedy, Drama', 'media_rate': 8.35, 'qtd_filmes': 4}
# {'_id': 'Drama, Fantasy', 'media_rate': 8.149999999999999, 'qtd_filmes': 4}
# {'_id': 'Comedy, Drama, Thriller', 'media_rate': 8.35, 'qtd_filmes': 4}
# {'_id': 'Animation, Drama, Family', 'media_rate': 8.1, 'qtd_filmes': 4}
# {'_id': 'Comedy, Drama, War', 'media_rate': 8.25, 'qtd_filmes': 4}
# {'_id': 'Animation, Adventure, Fantasy', 'media_rate': 8.25, 'qtd_filmes': 4}
# {'_id': 'Drama, Family, Sport', 'media_rate': 8.25, 'qtd_filmes': 4}
# {'_id': 'Drama, Mystery, War', 'media_rate': 8.350000000000001, 'qtd_filmes': 4}
# {'_id': 'Comedy, Drama, Family', 'media_rate': 8.4, 'qtd_filmes': 4}
# {'_id': 'Comedy, Drama, Musical', 'media_rate': 8.1, 'qtd_filmes': 4}
# {'_id': 'Biography, Drama, Sport', 'media_rate': 8.2, 'qtd_filmes': 4}
# {'_id': 'Drama, Sport', 'media_rate': 8.1, 'qtd_filmes': 4}
# {'_id': 'Crime, Mystery, Thriller', 'media_rate': 8.4, 'qtd_filmes': 4}
# {'_id': 'Drama, Sci-Fi', 'media_rate': 8.25, 'qtd_filmes': 4}
# {'_id': 'Animation, Comedy, Drama', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Animation, Drama, War', 'media_rate': 8.5, 'qtd_filmes': 2}
# {'_id': 'Action, Comedy, Romance', 'media_rate': 8.2, 'qtd_filmes': 2}
# {'_id': 'Comedy, Drama, Fantasy', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Drama, Horror, Thriller', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Comedy, Musical, Romance', 'media_rate': 8.3, 'qtd_filmes': 2}
# {'_id': 'Drama, Horror', 'media_rate': 8.4, 'qtd_filmes': 2}
# {'_id': 'Action, Drama, Sci-Fi', 'media_rate': 8.2, 'qtd_filmes': 2}
# {'_id': 'Adventure, Comedy, Crime', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Action, Sci-Fi, Thriller', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Comedy, Crime', 'media_rate': 8.3, 'qtd_filmes': 2}
# {'_id': 'Drama, Romance, Thriller', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Horror, Mystery, Thriller', 'media_rate': 8.5, 'qtd_filmes': 2}
# {'_id': 'Crime, Drama, Fantasy', 'media_rate': 8.6, 'qtd_filmes': 2}
# {'_id': 'Adventure, Drama, Western', 'media_rate': 8.2, 'qtd_filmes': 2}
# {'_id': 'Horror, Mystery, Sci-Fi', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Drama, Mystery', 'media_rate': 8.3, 'qtd_filmes': 2}
# {'_id': 'Animation, Action, Drama', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Comedy, Music, Romance', 'media_rate': 8.2, 'qtd_filmes': 2}
# {'_id': 'Crime, Drama, Film-Noir', 'media_rate': 8.3, 'qtd_filmes': 2}
# {'_id': 'Comedy, Crime, Sport', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Drama, Thriller, War', 'media_rate': 8.3, 'qtd_filmes': 2}
# {'_id': 'Drama, Fantasy, Music', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Adventure, Sci-Fi', 'media_rate': 8.3, 'qtd_filmes': 2}
# {'_id': 'Drama, Family, Fantasy', 'media_rate': 8.6, 'qtd_filmes': 2}
# {'_id': 'Mystery, Romance, Thriller', 'media_rate': 8.3, 'qtd_filmes': 2}
# {'_id': 'Animation, Drama, Fantasy', 'media_rate': 8.4, 'qtd_filmes': 2}
# {'_id': 'Adventure, Mystery, Thriller', 'media_rate': 8.3, 'qtd_filmes': 2}
# {'_id': 'Comedy, War', 'media_rate': 8.2, 'qtd_filmes': 2}
# {'_id': 'Crime, Drama, Sci-Fi', 'media_rate': 8.3, 'qtd_filmes': 2}
# {'_id': 'Adventure, Comedy, Fantasy', 'media_rate': 8.2, 'qtd_filmes': 2}
# {'_id': 'Drama, Romance, War', 'media_rate': 8.5, 'qtd_filmes': 2}
# {'_id': 'Action, Drama, Sport', 'media_rate': 8.2, 'qtd_filmes': 2}
# {'_id': 'Drama, Fantasy, Horror', 'media_rate': 8.3, 'qtd_filmes': 2}
# {'_id': 'Comedy, Crime, Romance', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Horror, Sci-Fi', 'media_rate': 8.4, 'qtd_filmes': 2}
# {'_id': 'Action, Biography, Crime', 'media_rate': 8.2, 'qtd_filmes': 2}
# {'_id': 'Adventure, Family, Fantasy', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Comedy, Drama, Sci-Fi', 'media_rate': 8.1, 'qtd_filmes': 2}
# {'_id': 'Drama, Fantasy, War', 'media_rate': 8.2, 'qtd_filmes': 2}
# {'_id': 'Drama, Musical', 'media_rate': 8.5, 'qtd_filmes': 2}
# {'_id': 'Adventure, Drama, Musical', 'media_rate': 8.1, 'qtd_filmes': 2}

# %%
# Índice simples para buscas rápidas por Gênero
collection.create_index([("Genre", pymongo.ASCENDING)])
print("Índice criado no campo Genre.")
# Out:
# Índice criado no campo Genre.
