# %% [markdown]
# # Análise Básica do Dataset (Movies)
# Este notebook carrega o arquivo `movies.csv` e executa análises básicas solicitadas: visualização de amostras, dimensões, tipos, estatísticas descritivas, nomes de colunas e valores ausentes.

# %%
# Importar bibliotecas e carregar o CSV
import pandas as pd

# Caminho do arquivo (use r'...' para lidar com caracteres especiais)
caminho = r'C:\Users\rafae\OneDrive\Desktop\Fatesg-IA-2\Ciência de dados\Atividade Manipulação Básica de Dados\movies.csv'

# Carregar dados
df = pd.read_csv(caminho)

# Visualizar forma geral
print('Dimensões iniciais -> Linhas:', df.shape[0], '| Colunas:', df.shape[1])
# Out:
# Dimensões iniciais -> Linhas: 4803 | Colunas: 24

# %%
# 2. Exiba as 8 primeiras e 8 últimas linhas
from IPython.display import display

print('8 primeiras linhas:')
display(df.head(8))
print('\n8 últimas linhas:')
display(df.tail(8))
# Out:
# 8 primeiras linhas:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
# 5      5  258000000                  Fantasy Action Adventure
# 6      6  260000000                          Animation Family
# 7      7  280000000          Action Adventure Science Fiction
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# 3                 http://www.thedarkknightrises.com/   49026
# 4               http://movies.disney.com/john-carter   49529
# ...

# %%
# 3. Número total de linhas e colunas
print(f"Linhas: {df.shape[0]}")
print(f"Colunas: {df.shape[1]}")
# Out:
# Linhas: 4803
# Colunas: 24

# %%
# 4. Tipos de cada coluna
# df.info() imprime diretamente o resumo das colunas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
# ...

# %%
# 5a. Estatísticas descritivas (apenas colunas numéricas por padrão)
df.describe()
# Out:
#              index        budget             id   popularity       revenue  \
# count  4803.000000  4.803000e+03    4803.000000  4803.000000  4.803000e+03
# mean   2401.000000  2.904504e+07   57165.484281    21.492301  8.226064e+07
# std    1386.651002  4.072239e+07   88694.614033    31.816650  1.628571e+08
# min       0.000000  0.000000e+00       5.000000     0.000000  0.000000e+00
# 25%    1200.500000  7.900000e+05    9014.500000     4.668070  0.000000e+00
# 50%    2401.000000  1.500000e+07   14629.000000    12.921594  1.917000e+07
# 75%    3601.500000  4.000000e+07   58610.500000    28.313505  9.291719e+07
# max    4802.000000  3.800000e+08  459488.000000   875.581305  2.787965e+09
#
#            runtime  vote_average    vote_count
# count  4801.000000   4803.000000   4803.000000
# mean    106.875859      6.092172    690.217989
# std      22.611935      1.194612   1234.585891
# min       0.000000      0.000000      0.000000
# 25%      94.000000      5.600000     54.000000
# ...

# %%
# 5b. Nomes das colunas
list(df.columns)
# Out:
# ['index',
#  'budget',
#  'genres',
#  'homepage',
#  'id',
#  'keywords',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'vote_average',
#  'vote_count',
#  'cast',
#  'crew',
#  'director']

# %%
# 5c. Valores ausentes em cada coluna
# Dica: use .sort_values(ascending=False) para ordenar do maior para o menor
df.isnull().sum().sort_values(ascending=False)
# Out:
# homepage                3091
# tagline                  844
# keywords                 412
# cast                      43
# director                  30
# genres                    28
# overview                   3
# runtime                    2
# release_date               1
# original_title             0
# id                         0
# index                      0
# budget                     0
# original_language          0
# production_countries       0
# popularity                 0
# spoken_languages           0
# revenue                    0
# production_companies       0
# status                     0
# vote_average               0
# title                      0
# vote_count                 0
# crew                       0
# dtype: int64

# %% [markdown]
# # 5d. Impressões gerais sobre o dataset
#
# Com base apenas na observação das características do arquivo:
#
# - Tamanho: o dataset possui 4803 linhas e 24 colunas, sugerindo boa quantidade de exemplos para análise exploratória.
# - Tipos de dados: há mistura de variáveis numéricas (por exemplo, `budget`, `revenue`, `popularity`, `vote_average`, `vote_count`) e categóricas/textuais (por exemplo, `genres`, `original_language`, `status`, `title`, `overview`). A coluna `release_date` aparece como texto e pode ser convertida para data.
# - Valores ausentes: maior incidência em `homepage` (muitos filmes não possuem página oficial) e `tagline`; também há ausências em `keywords`, `cast`, `director`, `genres`. Colunas numéricas têm poucos ou nenhum nulo.
# - Possíveis análises: relação entre `budget` e `revenue`; distribuição de `vote_average` e `runtime`; popularidade por gênero e por idioma; variações temporais após converter `release_date` para data (ano/mês).
# - Pré-processamento: recomenda-se padronizar tipos (datas), tratar ausentes (remover, imputar ou manter conforme objetivo), e eventualmente expandir colunas aninhadas (como `genres`, `production_companies`) se forem listas/strings estruturadas.
#
# Essas impressões são iniciais e servem para orientar próximos passos de limpeza e exploração.
