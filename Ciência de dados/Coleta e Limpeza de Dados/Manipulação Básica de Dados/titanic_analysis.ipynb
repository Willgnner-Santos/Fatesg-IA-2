# %%
import pandas as pd
import numpy as np

url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       4 url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Salvar o dataset limpo em um novo arquivo CSV (opcional)
# df_limpo.to_csv('titanic_limpo.csv', index=False)
# print("\nDataset limpo salvo como 'titanic_limpo.csv'.")

# %%
# Vasculhe os dados e encontre uma característica peculiar.
df.describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Vasculhe os dados e encontre uma característica peculiar.
# ----> 2 df.describe(include='all')
#
# NameError: name 'df' is not defined

# %%
# A coluna Ticket tem muitos valores únicos.
df['Ticket'].nunique()

# %%
# Remover todas as linhas com ao menos um valor ausente
df_drop_na = df.dropna()
len(df), len(df_drop_na)

# %%
# Criar FamilySize
df['FamilySize'] = df['SibSp'] + df['Parch']

# Média de sobrevivência por tamanho de família
df.groupby('FamilySize')['Survived'].mean()
