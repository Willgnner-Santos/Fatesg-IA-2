# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from google.colab import files

uploaded = files.upload()  # Abre janela para selecionar arquivo

# Armazena no diretório /content/
# Out:
#      <input type="file" id="files-63ce13eb-b108-4f6d-b2ef-df6295655c75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63ce13eb-b108-4f6d-b2ef-df6295655c75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Exibir as 8 primeiras linhas
print("=" * 100)
print("PRIMEIRAS 8 LINHAS DO DATASET")
print("=" * 100)
df.head(8)
# Out:
# ...
# PRIMEIRAS 8 LINHAS DO DATASET
# ...
#     GAME_ID     TEAM_ID  TEAM_NAME TEAM_ABBREVIATION    TEAM_CITY  HOME_TEAM  \
# 0  21200001  1610612764    Wizards               WAS   Washington  Cavaliers
# 1  21200001  1610612739  Cavaliers               CLE    Cleveland  Cavaliers
# 2  21200002  1610612748       Heat               MIA        Miami       Heat
# 3  21200002  1610612738    Celtics               BOS       Boston       Heat
# 4  21200003  1610612747     Lakers               LAL  Los Angeles     Lakers
# 5  21200003  1610612742  Mavericks               DAL       Dallas     Lakers
# 6  21200004  1610612761    Raptors               TOR      Toronto    Raptors
# 7  21200004  1610612754     Pacers               IND      Indiana    Raptors
#
#       MIN  FGM  FGA  FG_PCT  ...  TO  PF  PTS  PLUS_MINUS  EFG_PCT    PIE  \
# 0  240:00   32   90   0.356  ...  12  19   84         -10     0.32  42.60
# 1  240:00   36   79   0.456  ...  20  21   94          10     0.36  57.40
# ...

# %%
# Exibir as 8 últimas linhas
print("\n" + "=" * 100)
print("ÚLTIMAS 8 LINHAS DO DATASET")
print("=" * 100)
df.tail(8)
# Out:
# ...
# ÚLTIMAS 8 LINHAS DO DATASET
# ...
#         GAME_ID     TEAM_ID  TEAM_NAME TEAM_ABBREVIATION      TEAM_CITY  \
# 31332  22401227  1610612753      Magic               ORL        Orlando
# 31333  22401227  1610612752     Knicks               NYK       New York
# 31334  22401228  1610612744   Warriors               GSW   Golden State
# 31335  22401228  1610612742  Mavericks               DAL         Dallas
# 31336  22401229  1610612749      Bucks               MIL      Milwaukee
# 31337  22401229  1610612737      Hawks               ATL        Atlanta
# 31338  22401230  1610612760    Thunder               OKC  Oklahoma City
# 31339  22401230  1610612745    Rockets               HOU        Houston
#
#       HOME_TEAM     MIN  FGM  FGA  FG_PCT  ...  TO  PF  PTS  PLUS_MINUS  \
# 31332     Magic  240:00   36   86   0.419  ...  15  26   91          -9
# 31333     Magic  240:00   33   71   0.465  ...  17  16  100           9
# 31334  Warriors  240:00   49  103   0.476  ...  10  17  133         -10
# ...

# %%
# Obter dimensões do dataset
n_rows, n_cols = df.shape

print("\n" + "=" * 100)
print("DIMENSÕES DO DATASET")
print("=" * 100)
print(f"Número total de linhas (registros): {n_rows:,}")
print(f"Número total de colunas (variáveis): {n_cols}")
print(f"Total de células: {n_rows * n_cols:,}")

# Exibir nomes de todas as colunas
print(f"\nLista de colunas ({n_cols}):")
for i, col in enumerate(df.columns, 1):
    print(f"  {i:2d}. {col}")
# Out:
# ...
# DIMENSÕES DO DATASET
# ...
# Número total de linhas (registros): 31,340
# Número total de colunas (variáveis): 32
# Total de células: 1,002,880
#
# Lista de colunas (32):
#    1. GAME_ID
#    2. TEAM_ID
#    3. TEAM_NAME
#    4. TEAM_ABBREVIATION
#    5. TEAM_CITY
#    6. HOME_TEAM
#    7. MIN
#    8. FGM
#    9. FGA
#   10. FG_PCT
#   11. FG3M
#   12. FG3A
#   13. FG3_PCT
#   14. FTM
#   15. FTA
#   16. FT_PCT
#   17. OREB
#   18. DREB
#   19. REB
#   20. AST
#   21. STL
#   22. BLK
#   23. TO
#   24. PF
#   25. PTS
#   26. PLUS_MINUS
#   27. EFG_PCT
#   28. PIE
#   29. COVID_FLAG
#   30. RESULT
#   31. SEASON
#   32. WIN_PCT

# %%
# Exibir os tipos de dados de cada coluna
print("\n" + "=" * 100)
print("TIPOS DE DADOS POR COLUNA")
print("=" * 100)
print(df.dtypes)

# Resumo dos tipos de dados
print("\n" + "-" * 50)
print("RESUMO DOS TIPOS DE DADOS:")
print("-" * 50)
print(df.dtypes.value_counts())
# Out:
# ...
# TIPOS DE DADOS POR COLUNA
# ...
# GAME_ID                int64
# TEAM_ID                int64
# TEAM_NAME             object
# TEAM_ABBREVIATION     object
# TEAM_CITY             object
# HOME_TEAM             object
# MIN                   object
# FGM                    int64
# FGA                    int64
# FG_PCT               float64
# FG3M                   int64
# FG3A                   int64
# FG3_PCT              float64
# FTM                    int64
# FTA                    int64
# FT_PCT               float64
# OREB                   int64
# DREB                   int64
# REB                    int64
# AST                    int64
# STL                    int64
# BLK                    int64
# TO                     int64
# PF                     int64
# PTS                    int64
# PLUS_MINUS             int64
# EFG_PCT              float64
# PIE                  float64
# COVID_FLAG             int64
# RESULT                 int64
# SEASON                 int64
# ...

# %%
# 7.1 - Estatísticas descritivas das colunas numéricas
print("\n" + "=" * 100)
print("ESTATÍSTICAS DESCRITIVAS - COLUNAS NUMÉRICAS")
print("=" * 100)
df.describe()
# Out:
# ...
# ESTATÍSTICAS DESCRITIVAS - COLUNAS NUMÉRICAS
# ...
#             GAME_ID       TEAM_ID           FGM           FGA        FG_PCT  \
# count  3.134000e+04  3.134000e+04  31340.000000  31340.000000  31340.000000
# mean   2.179764e+07  1.610613e+09     39.891034     86.543969      0.461813
# std    3.773027e+05  8.651236e+00      5.376204      7.535348      0.055319
# min    2.120000e+07  1.610613e+09     19.000000     60.000000      0.269000
# 25%    2.150023e+07  1.610613e+09     36.000000     81.000000      0.424000
# 50%    2.180046e+07  1.610613e+09     40.000000     86.000000      0.461000
# 75%    2.210100e+07  1.610613e+09     43.000000     91.000000      0.500000
# max    2.240123e+07  1.610613e+09     65.000000    129.000000      0.689000
#
#                FG3M          FG3A       FG3_PCT           FTM           FTA  \
# count  31340.000000  31340.000000  31340.000000  31340.000000  31340.000000
# mean      10.644161     29.662444      0.357244     17.351500     22.583344
# ...

# %%
# 7.2 - Contagem de valores nulos (missing values)
print("\n" + "=" * 100)
print("CONTAGEM DE VALORES NULOS (MISSING VALUES)")
print("=" * 100)
valores_nulos = df.isnull().sum()
print(valores_nulos)

# Porcentagem de valores nulos
print("\n" + "-" * 50)
print("PORCENTAGEM DE VALORES NULOS:")
print("-" * 50)
percentual_nulos = (df.isnull().sum() / len(df)) * 100
print(percentual_nulos)
# Out:
# ...
# CONTAGEM DE VALORES NULOS (MISSING VALUES)
# ...
# GAME_ID               0
# TEAM_ID               0
# TEAM_NAME             0
# TEAM_ABBREVIATION     0
# TEAM_CITY             0
# HOME_TEAM            10
# MIN                   0
# FGM                   0
# FGA                   0
# FG_PCT                0
# FG3M                  0
# FG3A                  0
# FG3_PCT               0
# FTM                   0
# FTA                   0
# FT_PCT                0
# OREB                  0
# DREB                  0
# REB                   0
# AST                   0
# STL                   0
# BLK                   0
# TO                    0
# PF                    0
# PTS                   0
# PLUS_MINUS            0
# EFG_PCT               0
# PIE                   0
# COVID_FLAG            0
# RESULT                0
# SEASON                0
# WIN_PCT               0
# dtype: int64
#
# --------------------------------------------------
# PORCENTAGEM DE VALORES NULOS:
# ...

# %%
# 7.3 - Número de valores únicos por coluna
print("\n" + "=" * 100)
print("NÚMERO DE VALORES ÚNICOS POR COLUNA")
print("=" * 100)
valores_unicos = df.nunique()
print(valores_unicos)
# Out:
# ...
# NÚMERO DE VALORES ÚNICOS POR COLUNA
# ...
# GAME_ID              15668
# TEAM_ID                 30
# TEAM_NAME               31
# TEAM_ABBREVIATION       31
# TEAM_CITY               30
# HOME_TEAM               31
# MIN                      5
# FGM                     45
# FGA                     67
# FG_PCT                 357
# FG3M                    30
# FG3A                    62
# FG3_PCT                407
# FTM                     46
# FTA                     58
# FT_PCT                 350
# OREB                    31
# DREB                    44
# REB                     56
# AST                     44
# STL                     23
# BLK                     21
# TO                      31
# PF                      38
# PTS                    104
# PLUS_MINUS             122
# EFG_PCT                 59
# PIE                   4247
# COVID_FLAG               2
# RESULT                   2
# SEASON                  13
# WIN_PCT               1587
# dtype: int64

# %%
# 7.4 - Detectar duplicatas
print("\n" + "=" * 100)
print("DETECÇÃO DE DUPLICATAS")
print("=" * 100)
n_duplicatas = df.duplicated().sum()
print(f"Número de linhas duplicadas: {n_duplicatas}")
print(f"Percentual de duplicatas: {(n_duplicatas/len(df))*100:.2f}%")

if n_duplicatas > 0:
    print("\nPrimeiras linhas duplicadas:")
    print(df[df.duplicated(keep=False)].head(10))
# Out:
# ...
# DETECÇÃO DE DUPLICATAS
# ...
# Número de linhas duplicadas: 0
# Percentual de duplicatas: 0.00%

# %%
# 7.5 - Explorar colunas categóricas
print("\n" + "=" * 100)
print("EXPLORAÇÃO DE COLUNAS CATEGÓRICAS (TEXTO)")
print("=" * 100)

colunas_texto = df.select_dtypes(include=['object']).columns
print(f"Colunas categóricas/texto: {list(colunas_texto)}\n")

for col in colunas_texto:
    print(f"\n{col}:")
    print(f"  Valores únicos: {df[col].nunique()}")
    print(f"  Principais valores:")
# Out:
# ...
# EXPLORAÇÃO DE COLUNAS CATEGÓRICAS (TEXTO)
# ...
# Colunas categóricas/texto: ['TEAM_NAME', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'HOME_TEAM', 'MIN']
#
#
# TEAM_NAME:
#   Valores únicos: 31
#   Principais valores:
#
# TEAM_ABBREVIATION:
#   Valores únicos: 31
#   Principais valores:
#
# TEAM_CITY:
#   Valores únicos: 30
#   Principais valores:
#
# HOME_TEAM:
#   Valores únicos: 31
#   Principais valores:
#
# MIN:
#   Valores únicos: 5
#   Principais valores:
